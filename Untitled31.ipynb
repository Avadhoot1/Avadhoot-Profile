# %% [markdown]
# <a href="https://colab.research.google.com/github/Avadhoot1/Avadhoot-Profile/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Read your dataset
gold = pd.read_csv("/content/gold.csv")

# %%
gold
# Out:
#             Date    Open     High      Low   Close  Volume Currency
# 0     2000-01-04   289.5   289.50   280.00   283.7   21621      USD
# 1     2000-01-05   283.7   285.00   281.00   282.1   25448      USD
# 2     2000-01-06   281.6   282.80   280.20   282.4   19055      USD
# 3     2000-01-07   282.5   284.50   282.00   282.9   11266      USD
# 4     2000-01-10   282.4   283.90   281.80   282.7   30603      USD
# ...          ...     ...      ...      ...     ...     ...      ...
# 5698  2022-08-29  1748.4  1757.90  1731.40  1749.7  156220      USD
# 5699  2022-08-30  1749.8  1752.80  1732.90  1736.3  130664      USD
# 5700  2022-08-31  1735.5  1738.00  1720.60  1726.2  176731      USD
# 5701  2022-09-01  1723.0  1723.00  1699.10  1709.3  198618      USD
# 5702  2022-09-02  1707.9  1729.45  1707.05  1723.0       0      USD
#
# [5703 rows x 7 columns]

# %%
# 1. Convert Date column to datetime
gold["Date"] = pd.to_datetime(gold["Date"])

# %%
gold["Date"]
# Out:
# 0      2000-01-04
# 1      2000-01-05
# 2      2000-01-06
# 3      2000-01-07
# 4      2000-01-10
#           ...
# 5698   2022-08-29
# 5699   2022-08-30
# 5700   2022-08-31
# 5701   2022-09-01
# 5702   2022-09-02
# Name: Date, Length: 5703, dtype: datetime64[ns]

# %%
# 2. Set Date as index (useful for time-series analysis)
gold.set_index("Date", inplace=True)

# %%
# Check result
print(gold.head())
print(gold.index)
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2000-01-04  289.5  289.5  280.0  283.7   21621      USD
# 2000-01-05  283.7  285.0  281.0  282.1   25448      USD
# 2000-01-06  281.6  282.8  280.2  282.4   19055      USD
# 2000-01-07  282.5  284.5  282.0  282.9   11266      USD
# 2000-01-10  282.4  283.9  281.8  282.7   30603      USD
# DatetimeIndex(['2000-01-04', '2000-01-05', '2000-01-06', '2000-01-07',
#                '2000-01-10', '2000-01-11', '2000-01-12', '2000-01-13',
#                '2000-01-14', '2000-01-18',
#                ...
#                '2022-08-22', '2022-08-23', '2022-08-24', '2022-08-25',
#                '2022-08-26', '2022-08-29', '2022-08-30', '2022-08-31',
#                '2022-09-01', '2022-09-02'],
#               dtype='datetime64[ns]', name='Date', length=5703, freq=None)

# %%
gold.loc["2005-01-01":"2005-12-31"]   # Get all data for 2005
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2005-01-03  438.9  438.9  427.8  429.7   82846      USD
# 2005-01-04  430.4  431.3  424.8  429.2   54829      USD
# 2005-01-05  429.0  429.3  425.9  427.3   43721      USD
# 2005-01-06  427.0  428.3  421.1  421.6   65179      USD
# 2005-01-07  422.1  425.8  417.2  419.5   97972      USD
# ...           ...    ...    ...    ...     ...      ...
# 2005-12-23  505.9  508.8  502.2  505.2   28820      USD
# 2005-12-27  506.8  510.7  505.3  510.1   26598      USD
# 2005-12-28  510.4  520.2  509.7  516.3   49532      USD
# 2005-12-29  516.0  520.1  512.8  517.5   32726      USD
# 2005-12-30  518.1  520.4  514.7  519.7   28159      USD
#
# [251 rows x 6 columns]

# %%
gold.loc["2008"].head()
# First rows of 2008
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2008-01-02  837.5  864.9  837.5  860.0  137804      USD
# 2008-01-03  861.5  872.9  856.5  869.1  136253      USD
# 2008-01-04  866.1  871.8  857.0  865.7  122758      USD
# 2008-01-07  862.8  867.8  857.8  862.0   89731      USD
# 2008-01-08  860.7  884.0  859.4  880.3  125474      USD

# %%
if "Currency" in gold.columns:
    gold.drop(columns=["Currency"], inplace=True)

# %%
# Save cleaned version again
gold.to_csv("gold_cleaned_no_currency.csv")

# %%
print("✅ 'Currency' column deleted. New file saved as gold_cleaned_no_currency.csv")
# Out:
# ✅ 'Currency' column deleted. New file saved as gold_cleaned_no_currency.csv

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
gold = pd.read_csv("gold_cleaned_no_currency.csv", parse_dates=["Date"], index_col="Date")

# %%
X = gold[["Open", "High", "Low", "Volume"]]   # input features
y = gold["Close"]                             # target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False  # no shuffle for time-series
)

# %%
rf = RandomForestRegressor(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
print("📊 Model Evaluation")
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# 📊 Model Evaluation
# Mean Absolute Error (MAE): 13.345060911481331
# R² Score: 0.9891218869135397

# %%
last_row = X.iloc[[-1]]   # latest day’s features
next_day_pred = rf.predict(last_row)

# %%
print("\n💰 Predicted Next Day Close Price:", next_day_pred[0])
# Out:
# 💰 Predicted Next Day Close Price: 1719.7444999999993

# %% [markdown]
# Now Plot the Close, Open, High , low, Volume

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))
plt.plot(gold.index, gold["Open"], label="Open", alpha=0.7)
plt.plot(gold.index, gold["High"], label="High", alpha=0.7)
plt.plot(gold.index, gold["Low"], label="Low", alpha=0.7)
plt.plot(gold.index, gold["Close"], label="Close", alpha=0.9, linewidth=2)

plt.title("Gold Prices (Open, High, Low, Close)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Plot Volume separately

# %%
plt.figure(figsize=(14,4))
plt.bar(gold.index, gold["Volume"], color="orange", alpha=0.6)
plt.title("Gold Trading Volume")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# Line plot comparison

# %%
plt.figure(figsize=(14,6))
plt.plot(gold.index, gold["Open"], label="Open Price", alpha=0.7)
plt.plot(gold.index, gold["Close"], label="Close Price", alpha=0.9, linewidth=2)

plt.title("Gold: Open vs Close Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Difference (Close - Open)

# %%
gold["Diff"] = gold["Close"] - gold["Open"]

plt.figure(figsize=(14,4))
plt.plot(gold.index, gold["Diff"], color="purple", alpha=0.8)
plt.axhline(0, color="red", linestyle="--")
plt.title("Difference between Close and Open (Close - Open)")
plt.xlabel("Date")
plt.ylabel("Price Difference (USD)")
plt.grid(True)
plt.show()

# %%
bullish_days = (gold["Diff"] > 0).sum()
bearish_days = (gold["Diff"] < 0).sum()
neutral_days = (gold["Diff"] == 0).sum()

# %%
total_days = len(gold)

# %% [markdown]
# Percentages

# %%
bullish_pct = bullish_days / total_days * 100
bearish_pct = bearish_days / total_days * 100
neutral_pct = neutral_days / total_days * 100

# %%
print("📊 Gold Open vs Close Statistics")
print(f"Total trading days: {total_days}")
print(f"Days gold closed higher (bullish): {bullish_days} ({bullish_pct:.2f}%)")
print(f"Days gold closed lower (bearish): {bearish_days} ({bearish_pct:.2f}%)")
print(f"Days gold closed same as open: {neutral_days} ({neutral_pct:.2f}%)")
# Out:
# 📊 Gold Open vs Close Statistics
# Total trading days: 5703
# Days gold closed higher (bullish): 2903 (50.90%)
# Days gold closed lower (bearish): 2759 (48.38%)
# Days gold closed same as open: 41 (0.72%)

# %%
y_pred = rf.predict(X_test)

print("📊 Model Evaluation")
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# 📊 Model Evaluation
# Mean Absolute Error (MAE): 13.345060911481331
# R² Score: 0.9891218869135397

# %%
last_row = X.iloc[[-1]]
next_day_pred = rf.predict(last_row)

print("\n💰 Predicted Next Day Close Price:", next_day_pred[0])
# Out:
# 💰 Predicted Next Day Close Price: 1719.7444999999993

# %%
plt.figure(figsize=(14,6))
plt.plot(y_test.index, y_test.values, label="Actual Close Price", color="blue")
plt.plot(y_test.index, y_pred, label="Predicted Close Price", color="red", linestyle="--")
plt.title("Actual vs Predicted Gold Close Prices")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Short-term next-day prediction

# %%
last_row = X.iloc[[-1]]
next_day_pred = rf.predict(last_row)
print("💰 Predicted Next Day Close Price:", next_day_pred[0])
# Out:
# 💰 Predicted Next Day Close Price: 1719.7444999999993

# %%
import pandas as pd

# Put actual and predicted into a dataframe
results = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
}, index=y_test.index)

print(results.head(20))  # show first 20 rows

# Save results to CSV for further analysis
results.to_csv("/content/gold_cleaned_no_currency.csv")
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))
plt.plot(results.index, results["Actual"], label="Actual Close Price", color="blue")
plt.plot(results.index, results["Predicted"], label="Predicted Close Price", color="red", linestyle="--")

plt.title("Actual vs Predicted Gold Close Prices")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#             Actual  Predicted
# Date
# 2018-02-23  1330.3  1329.0175
# 2018-02-26  1332.8  1328.6080
# 2018-02-27  1318.6  1326.1245
# 2018-02-28  1317.9  1323.8530
# 2018-03-01  1305.2  1322.1250
# 2018-03-02  1323.4  1301.4935
# 2018-03-05  1319.9  1324.0980
# 2018-03-06  1335.2  1322.0120
# 2018-03-07  1327.6  1335.0135
# 2018-03-08  1321.7  1319.7205
# 2018-03-09  1324.0  1324.2055
# 2018-03-12  1320.8  1326.4230
# 2018-03-13  1327.1  1323.7590
# 2018-03-14  1325.6  1332.1340
# 2018-03-15  1317.8  1321.9425
# 2018-03-16  1312.3  1317.9090
# 2018-03-19  1317.8  1310.8780
# 2018-03-20  1311.9  1316.0075
# 2018-03-21  1321.5  1310.1395
# 2018-03-22  1327.4  1323.1490

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Predictions on test set
y_pred = rf.predict(X_test)

# Accuracy metrics
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("📊 Model Evaluation Metrics")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R² Score: {r2:.4f}")
# Out:
# 📊 Model Evaluation Metrics
# Mean Absolute Error (MAE): 30.71
# Root Mean Squared Error (RMSE): 53.51
# R² Score: 0.9550

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

y_pred = rf.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("RMSE:", rmse)
print("R²:", r2)
# Out:
# MAE: 30.71461262050877
# RMSE: 53.50888829489694
# R²: 0.9549854503013596

# %%
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
accuracy = 100 - mape

print(f"MAPE: {mape:.2f}%")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# MAPE: 1.71%
# Accuracy: 98.29%
